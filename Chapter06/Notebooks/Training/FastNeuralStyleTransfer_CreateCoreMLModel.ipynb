# %%
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", message="numpy.dtype size changed")
    warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
    warnings.filterwarnings("ignore", category=FutureWarning)
    
    import keras 
    print(keras.__version__)
# Out:
# 2.1.5

# %% [markdown]
# # Perceptual Losses for Real-Time Style Transfer and Super-Resolution
#
# Keras implementation of the network described in<a href='https://arxiv.org/abs/1603.08155'>Perceptual Losses for Real-Time Style Transfer and Super-Resolution by Justin Johnson, Alexandre Alahi, Li Fei-Fei</a> in in March 2016.
#
# The implementation is based on what was described in the <a href='http://course.fast.ai/lessons/lesson9.html'>FastAI's course on Generative Models</a>.

# %%
# %matplotlib inline

import importlib

import matplotlib
import matplotlib.pyplot as plt

from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import numpy as np
from PIL import Image # used to load images
import glob 

import tensorflow as tf

from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input, decode_predictions
from keras import backend as K

from vgg16_avg import VGG16_Avg

# %%
TARGET_SIZE = (320,320)

# %% [markdown]
# ## Training Data

# %% [markdown]
# Dataset from Fast.ai and can be downloaded from <a href='http://files.fast.ai/data/imagenet-sample-train.tar.gz'>here</a>.

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# We'll be using this image with VGG16. Therefore, we need to subtract the mean of each channel of the imagenet data and reverse the order of RGB->BGR since those are the preprocessing steps that the VGG authors did - so their model won't work unless we do the same thing.

# %%
def load_resize_image(img_path, target_size=TARGET_SIZE, preprocess_required=False):
    """
    
    """
    # Load image 
    img = Image.open(img_path)
    if img.mode is not "RGB":
        img = img.convert('RGB')
    
    if preprocess_required:
        # Get dimensions
        img_width, img_height = img.size
        half_img_width, half_img_height = img_width/2.0, img_height/2.0

        # Crop
        target_width = min(img_width, img_height)
        target_height = min(img_width, img_height)

        left = half_img_width - target_width/2
        top = half_img_height - target_height/2
        right = half_img_width + target_width/2
        bottom = half_img_height + target_height/2

        img = img.crop((left, top, right, bottom))

        # Resize 
        img = img.resize(target_size)
    
    return img

# %%
rn_mean = np.array([123.68, 116.779, 103.939], dtype=np.float32)

# %%
def preproc(x):     
    return (x-rn_mean)[:, :, :, ::-1]

# %% [markdown]
# When we generate images from this network, we'll need to undo the above preprocessing in order to view them.

# %%
def deproc(x, shape):
    return np.clip(x.reshape(shape)[:, :, :, ::-1] + rn_mean, 0, 255)

# %% [markdown]
# Load the style image

# %%
style = load_resize_image('data/Van_Gogh-Starry_Night.jpg', preprocess_required=True)
style
# Out:
# <PIL.Image.Image image mode=RGB size=320x320 at 0x181CE16DD0>

# %% [markdown]
# ---

# %% [markdown]
# ## Load model architecture and weights

# %%
class ReflectionPadding2D(keras.layers.Layer):
    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)        
        self.input_spec = [keras.layers.InputSpec(ndim=4)]
        super(ReflectionPadding2D, self).__init__(**kwargs)
        
    def compute_output_shape(self, s):
        return (s[0], s[1] + 2 * self.padding[0], s[2] + 2 * self.padding[1], s[3])

    def call(self, x, mask=None):
        w_pad,h_pad = self.padding
        return tf.pad(x, [[0,0], [h_pad,h_pad], [w_pad,w_pad], [0,0] ], 'REFLECT')
    
    def get_config(self):
        return super(ReflectionPadding2D, self).get_config()

# %%
# from keras.models import model_from_json
# with open('output/van-gogh-starry-night_style.json', 'r') as f:
#     with keras.utils.CustomObjectScope({'ReflectionPadding2D': ReflectionPadding2D}):
#         model = model_from_json(f.read())

# %% [markdown]
# ### Build Model
# (failed to load architecture - issue with Python 3 -> 2.7)

# %%
def conv_block(x, filters, size, stride=(2,2), mode='same', act=True):
    x = keras.layers.Conv2D(filters, kernel_size=(size, size), strides=stride, padding=mode)(x)
    x = keras.layers.BatchNormalization()(x)
    return keras.layers.Activation('relu')(x) if act else x

# %%
def up_block(x, filters, size):
    x = keras.layers.UpSampling2D()(x)
    x = keras.layers.Conv2D(filters, kernel_size=(size, size), padding='same')(x)
    x = keras.layers.BatchNormalization()(x)
    return keras.layers.Activation('relu')(x)

# %%
def res_crop(x):
    return x[:, 2:-2, 2:-2]

def res_crop_block(ip, nf=64, block_idx=0):
    x = conv_block(ip, nf, 3, (1,1), 'valid')
    x = conv_block(x,  nf, 3, (1,1), 'valid', False)
    ip = keras.layers.Lambda(res_crop, name='res_crop_{}'.format(block_idx))(ip)
    return keras.layers.add([x, ip])

# %%
def rescale_output(x):
    return (x+1)*127.5

shp = (320, 320, 3)
inp=keras.layers.Input(shp)

#x=ReflectionPadding2D((40, 40))(inp)
x = keras.layers.ZeroPadding2D(padding=(40, 40))(inp)

x=conv_block(x, 64, 9, (1,1))
x=conv_block(x, 64, 3)
x=conv_block(x, 64, 3)
for i in range(5): x=res_crop_block(x, 64, i)
x=up_block(x, 64, 3)
x=up_block(x, 64, 3)
x=keras.layers.Conv2D(3, kernel_size=(9, 9), activation='tanh', padding='same')(x)
outp=keras.layers.Lambda(rescale_output, name='rescale_output')(x)

# %%
vgg_inp=keras.layers.Input(shp)
vgg = VGG16(include_top=False, input_tensor=keras.layers.Lambda(preproc)(vgg_inp))
for l in vgg.layers: l.trainable=False

# %%
def get_outp(m, ln): 
    return m.get_layer("block{}_conv2".format(ln)).output

# %%
vgg_content = keras.models.Model(vgg_inp, [get_outp(vgg, o) for o in [2,3,4,5]])

# %%
style_targs = [K.variable(o) for o in
               vgg_content.predict(np.expand_dims(style,0))]

# %%
[K.eval(K.shape(o)) for o in style_targs]
# Out:
# [array([  1, 160, 160, 128], dtype=int32),
#  array([  1,  80,  80, 256], dtype=int32),
#  array([  1,  40,  40, 512], dtype=int32),
#  array([  1,  20,  20, 512], dtype=int32)]

# %%
vgg1 = vgg_content(vgg_inp)
vgg2 = vgg_content(outp)

# %%
def mean_sqr_b(diff): 
    dims = list(range(1,K.ndim(diff)))
    return K.expand_dims(K.sqrt(K.mean(diff**2, dims)), 0)

# %%
def gram_matrix_b(x):
    x = K.permute_dimensions(x, (0, 3, 1, 2))
    s = K.shape(x)
    feat = K.reshape(x, (s[0], s[1], s[2]*s[3]))
    return K.batch_dot(feat, K.permute_dimensions(feat, (0, 2, 1))
                      ) / K.prod(K.cast(s[1:], K.floatx()))

# %%
w=[0.1, 0.2, 0.6, 0.1]

def tot_loss(x):
    loss = 0 
    n = len(style_targs)
    for i in range(n):
        loss += mean_sqr_b(gram_matrix_b(x[i+n]) - gram_matrix_b(style_targs[i])) / 2.
        loss += mean_sqr_b(x[i]-x[i+n]) * w[i]
    return loss

# %%
loss = keras.layers.Lambda(tot_loss)(vgg1+vgg2)
m_style = keras.models.Model([inp, vgg_inp], loss)

# %%
m_style.compile('adam', 'mae')

# %%
K.set_value(m_style.optimizer.lr, 1e-4)

# %%
model = keras.models.Model(inp, outp)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 320, 320, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 400, 400, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 400, 400, 64) 15616       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 400, 400, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 400, 400, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 200, 200, 64) 36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 200, 200, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 200, 200, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 100, 100, 64) 36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 100, 100, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 100, 100, 64) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 98, 98, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 98, 98, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 98, 98, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 96, 96, 64)   36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 96, 96, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# res_crop_0 (Lambda)             (None, 96, 96, 64)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 96, 96, 64)   0           batch_normalization_20[0][0]
#                                                                  res_crop_0[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 94, 94, 64)   36928       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 94, 94, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 94, 94, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 92, 92, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 92, 92, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# res_crop_1 (Lambda)             (None, 92, 92, 64)   0           add_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 92, 92, 64)   0           batch_normalization_22[0][0]
#                                                                  res_crop_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 90, 90, 64)   36928       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 90, 90, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 90, 90, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 88, 88, 64)   36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 88, 88, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# res_crop_2 (Lambda)             (None, 88, 88, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 88, 88, 64)   0           batch_normalization_24[0][0]
#                                                                  res_crop_2[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 86, 86, 64)   36928       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 86, 86, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 86, 86, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 84, 84, 64)   36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 84, 84, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# res_crop_3 (Lambda)             (None, 84, 84, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 84, 84, 64)   0           batch_normalization_26[0][0]
#                                                                  res_crop_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 82, 82, 64)   36928       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 82, 82, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 82, 82, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 80, 80, 64)   36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 80, 80, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# res_crop_4 (Lambda)             (None, 80, 80, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 80, 80, 64)   0           batch_normalization_28[0][0]
#                                                                  res_crop_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 160, 160, 64) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 160, 160, 64) 36928       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 160, 160, 64) 256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 160, 160, 64) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 320, 320, 64) 0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 320, 320, 64) 36928       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 320, 320, 64) 256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 320, 320, 64) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 320, 320, 3)  15555       activation_21[0][0]
# __________________________________________________________________________________________________
# rescale_output (Lambda)         (None, 320, 320, 3)  0           conv2d_32[0][0]
# ==================================================================================================
# Total params: 552,003
# Trainable params: 550,083
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
# By inspecting the custom res_crop layer we can see that it just crops the shape by 2
res_crop_3_layer = [layer for layer in model.layers if layer.name == 'res_crop_3'][0] 
print("res_crop_3_layer input shape {}, output shape {}".format(
    res_crop_3_layer.input_shape, res_crop_3_layer.output_shape))
# Out:
# res_crop_3_layer input shape (None, 88, 88, 64), output shape (None, 84, 84, 64)

# %%
rescale_output_layer = [layer for layer in model.layers if layer.name == 'rescale_output'][0]
print("rescale_output_layer input shape {}, output shape {}".format(
    rescale_output_layer.input_shape, 
    rescale_output_layer.output_shape))
# Out:
# rescale_output_layer input shape (None, 320, 320, 3), output shape (None, 320, 320, 3)

# %%
model.load_weights('output/van-gogh-starry-night_style_2.h5')

# %%
img = load_resize_image('data/cat.jpg', preprocess_required=True) 
img = np.asarray(img, dtype='float32')
img = np.expand_dims(img, 0)
p = model.predict(img)
plt.imshow(np.round(p[0]).astype('uint8'));

# %%
img = load_resize_image('data/london_big-ben.jpg', preprocess_required=True) 
img = np.asarray(img, dtype='float32')
img = np.expand_dims(img, 0)
p = model.predict(img)
plt.imshow(np.round(p[0]).astype('uint8'));

# %% [markdown]
# ## Convert to CoreML

# %% [markdown]
# **References**
# https://apple.github.io/coremltools/generated/coremltools.models.neural_network.html

# %%
import coremltools

# %%
from coremltools.proto import NeuralNetwork_pb2

def convert_lambda(layer):
    print(layer.function)
    if layer.function == rescale_output:
        params = NeuralNetwork_pb2.CustomLayerParams()

        # The name of the Swift or Obj-C class that implements this layer.
        params.className = "RescaleOutputLambda"

        # The desciption is shown in Xcode's mlmodel viewer.
        params.description = "Rescale output to adjust for ReLu ((x+1)*127.5)"

        return params
    elif layer.function == res_crop:
        params = NeuralNetwork_pb2.CustomLayerParams()

        # The name of the Swift or Obj-C class that implements this layer.
        params.className = "ResCropBlockLambda"

        # The desciption is shown in Xcode's mlmodel viewer.
        params.description = "return x[:, 2:-2, 2:-2]"

        return params
    else:
        print("UNKNOWN LAYER")
    return None

# %%
coreml_model = coremltools.converters.keras.convert(model, 
                                                    input_names=['image'], 
                                                    image_input_names=['image'], 
                                                    output_names="output",
                                                    add_custom_layers=True,
                                                    custom_conversion_functions={ "Lambda": convert_lambda })
# Out:
# 0 : input_3, <keras.engine.topology.InputLayer object at 0x182839fbd0>
# 1 : zero_padding2d_2, <keras.layers.convolutional.ZeroPadding2D object at 0x182839fc10>
# 2 : conv2d_17, <keras.layers.convolutional.Conv2D object at 0x182839fcd0>
# 3 : batch_normalization_16, <keras.layers.normalization.BatchNormalization object at 0x182839fd10>
# 4 : activation_12, <keras.layers.core.Activation object at 0x181ee4ebd0>
# 5 : conv2d_18, <keras.layers.convolutional.Conv2D object at 0x181ce168d0>
# 6 : batch_normalization_17, <keras.layers.normalization.BatchNormalization object at 0x182839fc50>
# 7 : activation_13, <keras.layers.core.Activation object at 0x18221da9d0>
# 8 : conv2d_19, <keras.layers.convolutional.Conv2D object at 0x18234eb450>
# 9 : batch_normalization_18, <keras.layers.normalization.BatchNormalization object at 0x18234ebf90>
# 10 : activation_14, <keras.layers.core.Activation object at 0x18277b6ed0>
# 11 : conv2d_20, <keras.layers.convolutional.Conv2D object at 0x182d89af90>
# 12 : batch_normalization_19, <keras.layers.normalization.BatchNormalization object at 0x181c98c610>
# 13 : activation_15, <keras.layers.core.Activation object at 0x181f1664d0>
# 14 : conv2d_21, <keras.layers.convolutional.Conv2D object at 0x181f1f3b10>
# 15 : batch_normalization_20, <keras.layers.normalization.BatchNormalization object at 0x181f1f3cd0>
# 16 : res_crop_0, <keras.layers.core.Lambda object at 0x181f2670d0>
# <function res_crop at 0x18234c7758>
# 17 : add_6, <keras.layers.merge.Add object at 0x181fbec210>
# 18 : conv2d_22, <keras.layers.convolutional.Conv2D object at 0x181fc5c2d0>
# 19 : batch_normalization_21, <keras.layers.normalization.BatchNormalization object at 0x181fbec3d0>
# 20 : activation_16, <keras.layers.core.Activation object at 0x181fceeb50>
# 21 : conv2d_23, <keras.layers.convolutional.Conv2D object at 0x1821cdb590>
# 22 : batch_normalization_22, <keras.layers.normalization.BatchNormalization object at 0x1821cdb5d0>
# 23 : res_crop_1, <keras.layers.core.Lambda object at 0x1822221850>
# <function res_crop at 0x18234c7758>
# 24 : add_7, <keras.layers.merge.Add object at 0x18222b2d10>
# 25 : conv2d_24, <keras.layers.convolutional.Conv2D object at 0x18222b2ed0>
# 26 : batch_normalization_23, <keras.layers.normalization.BatchNormalization object at 0x18222b2fd0>
# 27 : activation_17, <keras.layers.core.Activation object at 0x1822bd8650>
# 28 : conv2d_25, <keras.layers.convolutional.Conv2D object at 0x1822bee090>
# 29 : batch_normalization_24, <keras.layers.normalization.BatchNormalization object at 0x1822bee0d0>
# 30 : res_crop_2, <keras.layers.core.Lambda object at 0x1822c5d050>
# <function res_crop at 0x18234c7758>
# 31 : add_8, <keras.layers.merge.Add object at 0x1822d5f9d0>
# 32 : conv2d_26, <keras.layers.convolutional.Conv2D object at 0x10c07b950>
# 33 : batch_normalization_25, <keras.layers.normalization.BatchNormalization object at 0x1822ceb810>
# 34 : activation_18, <keras.layers.core.Activation object at 0x182107d510>
# 35 : conv2d_27, <keras.layers.convolutional.Conv2D object at 0x182117e950>
# 36 : batch_normalization_26, <keras.layers.normalization.BatchNormalization object at 0x18210eb0d0>
# 37 : res_crop_3, <keras.layers.core.Lambda object at 0x181e9ae8d0>
# <function res_crop at 0x18234c7758>
# 38 : add_9, <keras.layers.merge.Add object at 0x18210fa350>
# 39 : conv2d_28, <keras.layers.convolutional.Conv2D object at 0x181ee7bb10>
# 40 : batch_normalization_27, <keras.layers.normalization.BatchNormalization object at 0x10bf2c490>
# 41 : activation_19, <keras.layers.core.Activation object at 0x1822e2ec90>
# 42 : conv2d_29, <keras.layers.convolutional.Conv2D object at 0x1822e4a6d0>
# 43 : batch_normalization_28, <keras.layers.normalization.BatchNormalization object at 0x1822e4a710>
# 44 : res_crop_4, <keras.layers.core.Lambda object at 0x1822ebb910>
# <function res_crop at 0x18234c7758>
# 45 : add_10, <keras.layers.merge.Add object at 0x182301e610>
# 46 : up_sampling2d_3, <keras.layers.convolutional.UpSampling2D object at 0x181c98c450>
# 47 : conv2d_30, <keras.layers.convolutional.Conv2D object at 0x1823009e90>
# 48 : batch_normalization_29, <keras.layers.normalization.BatchNormalization object at 0x18230433d0>
# 49 : activation_20, <keras.layers.core.Activation object at 0x1823135710>
# 50 : up_sampling2d_4, <keras.layers.convolutional.UpSampling2D object at 0x18230767d0>
# 51 : conv2d_31, <keras.layers.convolutional.Conv2D object at 0x1823135590>
# 52 : batch_normalization_30, <keras.layers.normalization.BatchNormalization object at 0x1823170490>
# 53 : activation_21, <keras.layers.core.Activation object at 0x182324a8d0>
# 54 : conv2d_32, <keras.layers.convolutional.Conv2D object at 0x1823135cd0>
# 55 : conv2d_32__activation__, <keras.layers.core.Activation object at 0x1828307990>
# 56 : rescale_output, <keras.layers.core.Lambda object at 0x182324ae90>
# <function rescale_output at 0x181be40de8>

# %%
coreml_model.author = 'Joshua Newnham'
coreml_model.license = 'BSD'
coreml_model.short_description = 'FastStyle Transfer with style Van Gogh Starry Night'
coreml_model.input_description['image'] = 'Preprocessed content image'
coreml_model.output_description['output'] = 'Stylized content image'

# %%
coreml_model.save('output/FastStyleTransferVanGoghStarryNight.mlmodel')

# %%
spec = coreml_model.get_spec()
for output in spec.description.output:  
    print(output.name)
# Out:
# output

# %% [markdown]
# For convenience we will convert the output to a Image (method taken from https://hackernoon.com/diy-prisma-fast-style-transfer-app-with-coreml-and-tensorflow-817c3b90dacd)

# %%
def convert_multiarray_output_to_image(model, feature_name, is_bgr=False):  
    """  
    Convert an output multiarray to be represented as an image  
    This will modify the Model_pb spec passed in.  
    Example:  
        model = coremltools.models.MLModel('MyNeuralNetwork.mlmodel')  
        spec = model.get_spec()  
        convert_multiarray_output_to_image(spec,'imageOutput',is_bgr=False)  
        newModel = coremltools.models.MLModel(spec)  
        newModel.save('MyNeuralNetworkWithImageOutput.mlmodel')  
    Parameters  
    ----------  
    spec: Model_pb  
        The specification containing the output feature to convert  
    feature_name: str  
        The name of the multiarray output feature you want to convert  
    is_bgr: boolean  
        If multiarray has 3 channels, set to True for RGB pixel order or false for BGR  
    """  
    
    spec = model.get_spec() 
    
    for output in spec.description.output:  
        if output.name != feature_name:  
            continue  
        if output.type.WhichOneof('Type') != 'multiArrayType':  
            raise ValueError("%s is not a multiarray type" % output.name)  
        array_shape = tuple(output.type.multiArrayType.shape)  
        channels, height, width = array_shape  
        from coremltools.proto import FeatureTypes_pb2 as ft  
        if channels == 1:  
            output.type.imageType.colorSpace = ft.ImageFeatureType.ColorSpace.Value('GRAYSCALE')  
        elif channels == 3:  
            if is_bgr:  
                output.type.imageType.colorSpace = ft.ImageFeatureType.ColorSpace.Value('BGR')  
            else:  
                output.type.imageType.colorSpace = ft.ImageFeatureType.ColorSpace.Value('RGB')  
        else:  
            raise ValueError("Channel Value %d not supported for image inputs" % channels)  
            
        output.type.imageType.width = width  
        output.type.imageType.height = height
        
    return coremltools.models.MLModel(spec)

# %%
converted_output_coreml_model = convert_multiarray_output_to_image(
    coreml_model,
    'output',
    is_bgr=False)

# %%
converted_output_coreml_model.save('output/FastStyleTransferVanGoghStarryNight.mlmodel')
